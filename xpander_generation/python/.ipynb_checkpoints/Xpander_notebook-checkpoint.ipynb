# %% [markdown]
# Building the graph:

# %%
import networkx as nx
import math
import random
f = open('out.txt_mat','r')
lines = f.readlines()
G=nx.Graph()
for i, line in enumerate(lines):    
    vertices = line.split(" ")
    G.add_edge(int(vertices[0]),int(vertices[1]),capacity = 1)

# %% [markdown]
# Initializing:

# %%
S_main = dict()
size = nx.number_of_nodes(G)
deg = nx.degree(G)[0]
for i in range(size):
    S_main[i] = math.floor(deg/3)


P_main = dict()
for i in range(len(S_main)):
    p = list()
    p.append(i)
    P_main[i] = p

r = (deg * size )/ (150 * math.log(size,2))

# %%
def toEdges(nodeList):
    edges = list()
    for i in range(len(nodeList)- 1):
        edge = list()
        edge.append(nodeList[i])
        edge.append(nodeList[i+1])
        edges.append(edge)
    return edges
def findPath(source,target,G):
    #need to exent this to the case where its not a simple path
    return nx.shortest_path(G,source,target)
def denseGraph(G,W):
    nodes = G.nodes()
    for i in nodes:
        if(G.degree(i)<(3*deg)/4 + 2):
            G.remove_node(i)
    return G

def buildPath(node,flow_table):
    while (flow_table[node]):
        next_node = flow_table[node].pop()
        if(next_node=='t'):
            p = list()
            p.append(node)
            return p
        else:
            p = list()
            p.append(node)
            p.append(buildPath(next_node,flow_table))
            return p
    raise Exeption("path not found") 

def updatePaths(G,source_nodes,target_nodes):
    G = G.copy()
    P = dict()
    for i in range(len(source_nodes)):
        G.add_edge('s',source_nodes[i],capacity = 1)
    for i in range(len(target_nodes)):
        G.add_edge('t',target_nodes[i],capacity = 1)
    flow_value, flow_dict = nx.maximum_flow(G,'s','t')
    flow_table = dict()
    for i in flow_dict.keys():
        flow_table[i] = list()
        for j in flow_dict[i].keys():
            if(flow_dict[i][j]==1):
                flow_table[i].append(j)
    for node in flow_table['s']:
        P[node] = buildPath(node,flow_table)
        if(len(P[node])>=2):
            print("new path: " + P[node])
    return P

# %%
S = dict(S_main)
P = dict(P_main)
G_l = G.copy()
W = list()
for l in range(math.floor(1000)):
    
    #generate next nodes.
    pair = random.sample(S.keys(),2)
    nextNodes = dict()
    for i in range(2):
        nextNodes[i] = pair[i]
        S[pair[i]]-=1;
        if(S[pair[i]]==0):
            S.pop(pair[i])
    #find next outer paths
    P_1 = P[nextNodes[0]]
    P_2 = P[nextNodes[1]]

    #compute G_l+1
    Q_l_tag = toEdges(findPath(P_1[len(P_1)-1],P_2[len(P_2)-1],G_tag))
    G_l.remove_edges_from(list(Q_l_tag))
    dense_G_l = denseGraph(G_l,Q_l_tag)
    
    #now to update paths
    G_tag = nx.Graph()
    for i in P:
        if i == nextNodes[0] or i==nextNodes[1]:
            #print("i " + str(i))
            continue
        G_tag.add_edges_from(toEdges(P[i]))
    G_tag.add_edges_from(G_l.edges())
    P = updatePaths(G_tag,list(S.keys()),dense_G_l.nodes())
    W = W + Q_l_tag
    G_l = dense_G_l
    Q_l = toEdges(P_1) + Q_l_tag + toEdges(P_2[::-1])
    print("s: " + str(nextNodes[0]) + " " + "t: " + str(nextNodes[1]))
    print(Q_l)
# Out:
# s: 899 t: 856
# [[899, 856]]
# s: 448 t: 573
# [[448, 270], [270, 573]]
# s: 122 t: 883
# [[122, 235], [235, 883]]
# s: 472 t: 485
# [[472, 267], [267, 177], [177, 485]]
# s: 511 t: 888
# [[511, 89], [89, 360], [360, 888]]
# s: 813 t: 152
# [[813, 377], [377, 152]]
# s: 727 t: 43
# [[727, 530], [530, 43]]
# s: 757 t: 213
# [[757, 98], [98, 213]]
# s: 887 t: 278
# [[887, 382], [382, 278]]
# s: 122 t: 877
# [[122, 0], [0, 413], [413, 877]]
# s: 50 t: 513
# [[50, 269], [269, 513]]
# s: 181 t: 844
# [[181, 1], [1, 142], [142, 844]]
# s: 640 t: 442
# [[640, 529], [529, 310], [310, 442]]
# s: 293 t: 279
# [[293, 746], [746, 126], [126, 279]]
# s: 729 t: 537
# [[729, 716], [716, 537]]
# s: 794 t: 170
# [[794, 112], [112, 273], [273, 170]]
# s: 382 t: 488
# [[382, 259], [259, 488]]
# s: 685 t: 155
# [[685, 523], [523, 155]]
# s: 40 t: 143
# [[40, 161], [161, 143]]
# s: 829 t: 206
# [[829, 413], [413, 528], [528, 206]]
# s: 517 t: 36
# [[517, 874], [874, 389], [389, 36]]
# s: 452 t: 349
# [[452, 321], [321, 349]]
# s: 135 t: 149
# [[135, 462], [462, 286], [286, 149]]
# s: 391 t: 571
# [[391, 776], [776, 495], [495, 571]]
# s: 893 t: 420
# [[893, 238], [238, 420]]
# s: 713 t: 787
# [[713, 661], [661, 787]]
# s: 755 t: 128
# [[755, 305], [305, 128]]
# s: 574 t: 246
# [[574, 829], [829, 540], [540, 246]]
# s: 640 t: 592
# [[640, 892], [892, 592]]
# s: 0 t: 264
# [[0, 466], [466, 264]]
# s: 84 t: 588
# [[84, 160], [160, 588]]
# s: 653 t: 300
# [[653, 568], [568, 300]]
# s: 639 t: 899
# [[639, 164], [164, 610], [610, 899]]
# s: 472 t: 405
# [[472, 164], [164, 78], [78, 405]]
# s: 5 t: 245
# [[5, 391], [391, 245]]
# s: 709 t: 555
# [[709, 775], [775, 555]]
# s: 481 t: 390
# [[481, 598], [598, 390]]
# s: 631 t: 492
# [[631, 756], [756, 492]]
# s: 741 t: 842
# [[741, 461], [461, 842]]
# s: 270 t: 586
# [[270, 50], [50, 586]]
# s: 33 t: 455
# [[33, 669], [669, 406], [406, 455]]
# s: 434 t: 872
# [[434, 872]]
# s: 56 t: 18
# [[56, 96], [96, 18]]
# s: 18 t: 46
# [[18, 613], [613, 46]]
# s: 769 t: 748
# [[769, 124], [124, 748]]
# s: 162 t: 112
# [[162, 1], [1, 266], [266, 112]]
# s: 482 t: 896
# [[482, 34], [34, 896]]
# s: 59 t: 644
# [[59, 578], [578, 423], [423, 644]]
# s: 274 t: 407
# [[274, 182], [182, 821], [821, 407]]
# s: 534 t: 539
# [[534, 802], [802, 83], [83, 539]]
# s: 413 t: 113
# [[413, 30], [30, 838], [838, 113]]
# s: 13 t: 22
# [[13, 51], [51, 425], [425, 22]]
# s: 729 t: 465
# [[729, 256], [256, 465]]
# s: 457 t: 462
# [[457, 480], [480, 355], [355, 462]]
# s: 176 t: 740
# [[176, 62], [62, 690], [690, 740]]
# s: 23 t: 700
# [[23, 512], [512, 700]]
# s: 262 t: 824
# [[262, 105], [105, 824]]
# s: 8 t: 549
# [[8, 212], [212, 549]]
# s: 758 t: 230
# [[758, 168], [168, 230]]
# s: 669 t: 897
# [[669, 349], [349, 897]]
# s: 26 t: 160
# [[26, 37], [37, 606], [606, 160]]
# s: 432 t: 302
# [[432, 302]]
# s: 23 t: 486
# [[23, 716], [716, 486]]
# s: 9 t: 762
# [[9, 205], [205, 762]]
# s: 698 t: 382
# [[698, 569], [569, 191], [191, 382]]
# s: 103 t: 96
# [[103, 76], [76, 709], [709, 96]]
# s: 487 t: 330
# [[487, 162], [162, 255], [255, 330]]
# s: 390 t: 536
# [[390, 138], [138, 536]]
# s: 137 t: 886
# [[137, 683], [683, 886]]
# s: 312 t: 68
# [[312, 3], [3, 68]]
# s: 887 t: 618
# [[887, 708], [708, 618]]
# s: 553 t: 489
# [[553, 730], [730, 489]]
# s: 840 t: 857
# [[840, 874], [874, 607], [607, 857]]
# s: 410 t: 657
# [[410, 703], [703, 657]]
# s: 420 t: 263
# [[420, 263]]
# s: 840 t: 650
# [[840, 578], [578, 691], [691, 650]]
# s: 653 t: 198
# [[653, 626], [626, 198]]
# s: 811 t: 881
# [[811, 173], [173, 881]]
# s: 325 t: 246
# [[325, 281], [281, 353], [353, 246]]
# s: 436 t: 392
# [[436, 300], [300, 392]]
# s: 281 t: 731
# [[281, 847], [847, 444], [444, 731]]
# s: 628 t: 49
# [[628, 303], [303, 49]]
# s: 661 t: 683
# [[661, 297], [297, 306], [306, 683]]
# s: 400 t: 534
# [[400, 270], [270, 534]]
# s: 9 t: 262
# [[9, 159], [159, 262]]
# s: 790 t: 736
# [[790, 406], [406, 2], [2, 736]]
# s: 20 t: 178
# [[20, 147], [147, 488], [488, 178]]
# s: 17 t: 892
# [[17, 141], [141, 566], [566, 892]]
# s: 468 t: 701
# [[468, 448], [448, 701]]
# s: 437 t: 516
# [[437, 70], [70, 516]]
# s: 541 t: 70
# [[541, 808], [808, 70]]
# s: 197 t: 74
# [[197, 798], [798, 74]]
# s: 533 t: 182
# [[533, 222], [222, 101], [101, 182]]
# s: 785 t: 797
# [[785, 597], [597, 760], [760, 797]]
# s: 180 t: 43
# [[180, 681], [681, 43]]
# s: 49 t: 843
# [[49, 479], [479, 843]]
# s: 637 t: 51
# [[637, 774], [774, 623], [623, 51]]
# s: 847 t: 487
# [[847, 62], [62, 187], [187, 487]]
# s: 804 t: 762
# [[804, 86], [86, 215], [215, 762]]
# s: 320 t: 209
# [[320, 88], [88, 480], [480, 209]]
